# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
combine = pd.read_csv('C:/Users/Hp/Downloads/newdata/products.csv')
dist = pd.read_csv('C:/Users/Hp/Downloads/newdata/districts.csv')

# %%
all_data = pd.concat([combine, dist])
combine = combine.rename(columns={'Provider/Company Name': 'Company'}, index={'ONE': 'Row_1'})
all_data.head(50)
# Out:
#       LP ID                                     URL  \
# 0   13117.0              https://www.splashmath.com
# 1   66933.0                    https://abcmouse.com
# 2   50479.0                   https://www.abcya.com
# 3   92993.0                   http://www.aleks.com/
# 4   73104.0            https://www.achieve3000.com/
# 5   37600.0           http://www.activelylearn.com/
# 6   18663.0              http://www.adaptedmind.com
# 7   65131.0                 http://www.amplify.com/
# 8   26491.0                 http://www.answers.com/
# 9   56441.0                  http://www.audible.com
# 10  89802.0                    http://bartleby.com/
# 11  72703.0                http://betterlesson.com/
# 12  76889.0             https://www.blackboard.com/
# 13  49563.0                https://bookcreator.com/
# 14  55589.0                http://www.brainpop.com/
# 15  84652.0                     http://www.ck12.org
# 16  16633.0                http://www.cnn.com/cnn10
# ...

# %%
combine.head()
# Out:
#    LP ID                           URL  Product Name                Company  \
# 0  13117    https://www.splashmath.com   SplashLearn          StudyPad Inc.
# 1  66933          https://abcmouse.com  ABCmouse.com  Age of Learning, Inc
# 2  50479         https://www.abcya.com        ABCya!         ABCya.com, LLC
# 3  92993         http://www.aleks.com/         ALEKS    McGraw-Hill PreK-12
# 4  73104  https://www.achieve3000.com/   Achieve3000            Achieve3000
#
#             Sector(s)                         Primary Essential Function
# 0             PreK-12                    LC - Digital Learning Platforms
# 1             PreK-12                    LC - Digital Learning Platforms
# 2             PreK-12  LC - Sites, Resources & Reference - Games & Si...
# 3  PreK-12; Higher Ed                    LC - Digital Learning Platforms
# 4             PreK-12                    LC - Digital Learning Platforms

# %%
# Out:
# pandas.core.series.Series
